# %%
# !pip install bert-score

# %% [markdown]
# repeate the below step for all the responses individually obtained through parent-document retrival and rag fusion

# %%
from bert_score import score

# Example texts
candidates = [""]#add the obtained result for each query
references = [""]# add the corresponding result

# Calculate BERTScore
P, R, F1 = score(candidates, references, lang='en', verbose=True)

# Print scores
print(f"Precision: {P.mean()}")
print(f"Recall: {R.mean()}")
print(f"F1 Score: {F1.mean()}")
